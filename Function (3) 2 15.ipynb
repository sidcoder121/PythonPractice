# %% [markdown]
# 1. Write a function to add two numbers.

# %%
def add_numbers(a, b):
    return a + b

result = add_numbers(int(input("Enter first number: ")), int(input("Enter second number: ")))
print(result)
# Out:
# Enter first number: 10
# Enter second number: 60
# 70

# %% [markdown]
# 2.Write a function to calculate the power of a number with default exponent as 2

# %%
def power(base, exponent=2):
    return base ** exponent


result = power(int(input("Enter thee  number:")))
print(result)
# Out:
# Enter thee  number:45
# 2025

# %% [markdown]
# 3.Write a function that takes keyword arguments and prints a greeting.

# %%
def greet(name, message="Hello"):
    print(f"{message}, {name}!")

greet(name=(input("Enter the name:")), message=(input("Enter your message:")))
# Out:
# Enter the name:goutam
# Enter your message:
# , goutam!

# %% [markdown]
# 4.Write a recursive function to calculate the factorial of a number.

# %%
def factorial(n):
    if n == 1:
        return 1
    else:
        return n * factorial(n-1)

result
# Out:
# 2025

# %% [markdown]
# 5.Write a recursive function to find the nth Fibonacci number.

# %%
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n-1) + fibonacci(n-2)

result = fibonacci(10)
print(result)
# Out:
# 55

# %% [markdown]
# 6.Write a Python program to sort a list of tuples based on the second element using a lambda function.

# %%
data = [(1, 4), (3, 1), (5, 9), (2, 7)]
data.sort(key=lambda x: x[1])

print(data)
# Out:
# [(3, 1), (1, 4), (2, 7), (5, 9)]

# %% [markdown]
# 7.Write a closure function that returns a function to multiply by a given factor.

# %%
def multiplier(factor):
    def multiply_by_factor(number):
        return number * factor
    return multiply_by_factor

multiply_by_5 = multiplier(5)

print(multiply_by_5(10))
# Out:
# 50

# %% [markdown]
# 8.Write a decorator that logs the arguments and return value of a function.

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print(f"Arguments: {args}, {kwargs}")
        result = func(*args, **kwargs)
        print(f"Return value: {result}")
        return result
    return wrapper

@logger
def add(a, b):
    return a + b

add(5, 3)
# Out:
# Arguments: (5, 3), {}
# Return value: 8
# 8

# %% [markdown]
# 9.Write a higher-order function that applies a function to every element in a list.

# %%
def apply_function(data, func):
    return [func(x) for x in data]

result = apply_function([1, 2, 3, 4], lambda x: x**2)
print(result)
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# 10.Write a function that takes a variable number of arguments and returns their sum.

# %%
def sum_all(*args):
    return sum(args)

result = sum_all(1, 2, 3, 4, 5)
print(result)
# Out:
# 15

# %% [markdown]
# 11.Write a function that accepts variable keyword arguments and prints a formatted string.

# %%
def display_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

display_info(name="Alice", age=30, city="New York")
# Out:
# name: Alice
# age: 30
# city: New York

# %% [markdown]
# 12.Write a memoized version of the Fibonacci function to improve performance.

# %%
def memoize_fib(f):
    memo = {}
    def wrapper(n):
        if n not in memo:
            memo[n] = f(n)
        return memo[n]
    return wrapper

@memoize_fib
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

print(fibonacci(10))
# Out:
# 55

# %% [markdown]
# 13.Write a function that checks whether a number is prime.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print(is_prime(30))
# Out:
# False

# %% [markdown]
# 14.Write a function that uses nested functions to calculate compound interest.

# %%
def compound_interest(principal, rate, time):
    def calculate():
        return principal * ((1 + rate) ** time)

    return calculate()

result = compound_interest(1000, 0.05, 2)
print(result)
# Out:
# 1102.5

# %% [markdown]
# 15.Write two functions and create a third function that composes them.

# %%
def multiply_by_2(x):
    return x * 2

def add_3(x):
    return x + 3

def compose(f, g):
    return lambda x: f(g(x))

new_function = compose(multiply_by_2, add_3)
print(new_function(5))
# Out:
# 16
